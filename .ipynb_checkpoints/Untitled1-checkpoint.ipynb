# %%
import numpy as np
import matplotlib.pylot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pylot as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = [3,5,9,"Clau es",[9,8]]
print(a[0],a[1],a[2])
print (a[-1],a[-2],a[-3],a[-4])
print(a[2],a[3][0])
print(a[3][2])
print(3*a)
# Out:
# 3 5 9
# [9, 8] Clau es 9 5
# 9 C
# a
# [3, 5, 9, 'Clau es', [9, 8], 3, 5, 9, 'Clau es', [9, 8], 3, 5, 9, 'Clau es', [9, 8]]

# %%
x = np.linspace(0,np.p1,100)
y= np.tan(x)
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x = np.linspace(0,np.p1,100)
#       2 y= np.tan(x)
#       3 plt.plot(x,y)
#
# File ~/Documents/GitHub/FisiComp26c/jupyter-env/lib/python3.14/site-packages/numpy/__init__.py:792, in __getattr__(attr)
#     789     import numpy.char as char
#     790     return char.chararray
# --> 792 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'p1'
