# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as si
import scipy.optimize as so
import scipy.fft as sf

# %% [markdown]
# # Péndulo doble simplificado
# Las ecuaciones de movimiento son:
# Las variables son $\theta_1$, $\theta_2$
# $$
#
# $$
