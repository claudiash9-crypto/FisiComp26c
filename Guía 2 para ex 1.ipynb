# %% [markdown]
# ### **1. Escriba un código que sume los números múltiplos de $5$ y $17$ que hay entre $0$ y $100,000$, es decir, que sume $0 + 5 +$ $10 + 17 + 20 + 25 + 30 + 34 + 35 + 51 + ...$**
# y resulta que la respuesta es:
# $a , b = 0 , 0$
# for i in range$(0,100000,5):$
#    $ a += i$
# for i in range$(0,100000,17):$
#     $b += i$
# print('Resultado',a+b)

# %%
a=0
b=0
for i in range(0,100000,5):
    a+= i
    #a+=i es lo mismo que a=a+i
for i in range(0,100000,17):
    b+=1
print(a)
print(b)
print('Resultado',a+b)
# Out:
# 999950000
# 5883
# Resultado 999955883

# %% [markdown]
# ### **2. Cuenta cuántos números pares hay entre 1 y 10,000**

# %%
pares=[]
for i in range(0,10001):
    if i%2== 0:
#% es el módulo, se usa para saber si un num es par
        pares.append(i)
        #pares.apenndi(i) agrega los elementos a la lista pares
print(len(pares))
#len() cuenta cuántos elementos hay en la lista pares.
# Out:
# 5001

# %% [markdown]
# ### **3. Calcula la suma $\Sigma_{n=1}^{1000} \frac{1}{n^2}$**

# %%
resultado=0
for n in range(1,1000):
    resultado+=1/n**2
print('resultado', resultado)
# Out:
# resultado 1.6439335666815615

# %% [markdown]
# ### **4. Evalúa la función $f(x)=sin(x)+x^2$ para valores entre 0 y 10**

# %%
import numpy as np
x=np.arange(0,10,1)
y=np.sin(x) + x**2
print(y)
# Out:
# [ 0.          1.84147098  4.90929743  9.14112001 15.2431975  24.04107573
#  35.7205845  49.6569866  64.98935825 81.41211849]

# %%
import numpy as np
def f(x):
    return np.sin(x) + x**2

x = np.arange(0,10,1)
y = f(x)
print(y)
# Out:
# [ 0.          1.84147098  4.90929743  9.14112001 15.2431975  24.04107573
#  35.7205845  49.6569866  64.98935825 81.41211849]

# %% [markdown]
# ### **5. Grafica $f(x)=e^{-x^2}$**

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-3,3,100)
y=np.exp(-x**2)
plt.plot(x,y)
plt.title(r'función f(x)')
plt.xlabel(r'$x$'), plt.ylabel(r'$y$')
plt.grid(),plt.show()
# Out:
# (None, None)

# %% [markdown]
# ### **6. Calcula la derivada numérica de $f(x)=x^3$**

# %%
import numpy as np
h= 1e-5
#h es el paso o separación entre num
x=np.linspace(-5,5,100)
f=x**3
df=((x+h)**3 - (x-h)**3)/(2*h)
print(df)
# Out:
# [7.50000000e+01 7.20003061e+01 6.90618304e+01 6.61845730e+01
#  6.33685338e+01 6.06137129e+01 5.79201102e+01 5.52877257e+01
#  5.27165595e+01 5.02066116e+01 4.77578818e+01 4.53703704e+01
#  4.30440771e+01 4.07790021e+01 3.85751454e+01 3.64325069e+01
#  3.43510866e+01 3.23308846e+01 3.03719008e+01 2.84741353e+01
#  2.66375880e+01 2.48622590e+01 2.31481481e+01 2.14952556e+01
#  1.99035813e+01 1.83731252e+01 1.69038874e+01 1.54958678e+01
#  1.41490664e+01 1.28634833e+01 1.16391185e+01 1.04759718e+01
#  9.37404347e+00 8.33333333e+00 7.35384144e+00 6.43556780e+00
#  5.57851240e+00 4.78267524e+00 4.04805632e+00 3.37465565e+00
#  2.76247322e+00 2.21150903e+00 1.72176309e+00 1.29323538e+00
#  9.25925926e-01 6.19834711e-01 3.74961739e-01 1.91307010e-01
#  6.88705235e-02 7.65228048e-03 7.65228048e-03 6.88705235e-02
#  1.91307010e-01 3.74961739e-01 6.19834711e-01 9.25925926e-01
#  1.29323538e+00 1.72176309e+00 2.21150903e+00 2.76247322e+00
# ...

# %% [markdown]
# ### **7. Calcular el error de la derivada numérica**
# Sabemos que la derivada de la función $x^3$ es: $3x^2$

# %%
df_real= 3*x**2
error=abs(df_real -df)

# %% [markdown]
# ### **8. Grafica dicho error**

# %%
plt.semilogy(x,error)
plt.grid()
plt.show()

# %% [markdown]
# #### **Consejo para el examen**
# estructura de los códigos:
#     import numpy
#     crear x
#     definir función
#     graficar
# o si pide un loop:
#     inicializar variable
#     loop
#     acumular
#     print

# %% [markdown]
# ---------------------

# %% [markdown]
# # **Examen 1 (anterior)**

# %% [markdown]
# ### **1. Escribe un código que sume los números múltiplos de 5 y 17 que hay entre 0 y 100000, es decir que sume $0+5+10+17+20+25+30+34+35+51+...$**

# %%
a=0
b=0
for i in range(0,100000,5):
    a+=i
    #es lo mismo que a= a+i
for i in range(0,100000,17):
    b+=i
print('resultado',a+b)
# Out:
# resultado 1294082351

# %% [markdown]
# ### **2. Haga la gráfica de la función $f(x)=x-\frac{x^2}{2}+ \frac{x^3}{3}$ y de la función $ln(1+x)$ en la misma gráfica. Como se comparan las dos funciones anteriores en el intervalo $|x| < 1$**

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-0.99,1,100)
# en lugar de -1 se pone -0.99
#porque log(-1)=0

def f1(x):
    f1= x - (x**2/2) +(x**3/3)
    return f1

def f2(x):
    f2= np.log(1+x)
    return f2
    
f1=f1(x)
f2=f2(x)

plt.plot(x,f1, label='función 1')
plt.plot(x,f2, label='función 2')
plt.title('funciones')
plt.xlabel(r'x'), plt.ylabel(r'y')
plt.grid(), plt.legend(), plt.show()
# Out:
# (None, <matplotlib.legend.Legend at 0x111ce5450>, None)

# %% [markdown]
# ### **3. Realice una función que utilice la función rand() para simular un dado de 7 caras. Es decir, haga una función que proporcione un número entre 1 y 8. Por ejemplo:**
# dado()
# y a la salida, podría proporcionar el número 5

# %%
import numpy as np

def dado():
    x=int(np.random.rand()*8)+1
    return x
dado()
# Out:
# 7

# %% [markdown]
# ### **4. Realice una función que reciba un número de cuenta de exclusivamente 9 dígitos y que a la salida proporcione la suma y el producto de todos sus dígitos distintos de cero. Compruebe el funcionamiento de su función con algún número de cuenta. Ejemplos:**
# In: sumar_nc(456982671)
# Out: Suma= 48; Producto =725,760
# In: sumar_nc(623548)
# Out: El número no tiene 9 dígitos

# %%
import numpy as np
import matplotlib.pyplot as plt

def sumar_nc(n):
    if n < 100000000 or n > 999999999:
        print("El número no tiene 9 dígitos")
        return
    suma= 0
    producto =1

    while n>0:
        digito = n % 10
        if digito !=0:
            suma+= digito
            producto*= digito
        n= n//10
    print("suma=", suma, ";Producto=", producto)

# %%
sumar_nc(456982671)
sumar_nc(623548)
# Out:
# suma= 48 ;Producto= 725760
# El número no tiene 9 dígitos

# %%
sumar_nc(46287368710)
# Out:
# El número no tiene 9 dígitos
