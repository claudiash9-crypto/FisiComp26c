# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def primitiva_sim(f,x):
    integral, h=np.zeros_like(f), x[1]-x[0]
    integral[0] = 0.5*(17*f[0] +7*f[1] +f[2] +f[3])
    for i in range(1,len(x)-1):
        integral[i] += integral[i-1] +(f[i+1] +22*f[i] +f[i-1])
    integral[-1]+= integral[-2] +0.5*(17*f[-1] +7*f[-2] +f[-3] -)
    return integral*h/24
# Out:
#   Cell In[9], line 6
#     integral[-1]+= integral[-2] +0.5*(17*f[-1] +7*f[-2] +f[-3] -
#                                      ^
# SyntaxError: '(' was never closed

# %%
def primitiva(f,x):
    integral, h=np.zeros_like(f), x[1]-x[0]
    integral[0] = f[0] +26*f[1] -4*f[2] +6*f[3] -3*f[4]
    for i in range(1,len(x)-4):
        integral[i] += integral[i-1] +(f[i] +26*f[i+1] -4*f[i+2] +6*)
        print(i)
    #for i in range(-4,1):
        #integral[i-1] = integral[i-1]+ (23*f[i-1]+ 26*f[i-2]- 4*f[]
        #print(i-1)
    return integral
# Out:
#   Cell In[8], line 5
#     integral[i] += integral[i-1] +(f[i] +26*f[i+1] -4*f[i+2] +6*
#                                   ^
# SyntaxError: '(' was never closed

# %%
x = np.linspace(0,2*np.pi)
y = np.sin(x)
int_y_sim = primitiva_sim(y,x)
int_y = primitiva(y,x)
Y= 1-np.cos(x)
plt.plot(x,y, label= r'$\sin(x)$')
plt.plot(x,int_y_sim, label=r'Primitiva simétrica')
plt.plot(x,int_y, lable=r'Primitiva')
plt.plot(x,Y, label=r'$1-\cos(x)$')
plt.legend(), plt.grid(), plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 x = np.linspace(0,2*np.pi)
#       2 y = np.sin(x)
# ----> 3 int_y_sim = primitiva_sim(y,x)
#       4 int_y = primitiva(y,x)
#       5 Y= 1-np.cos(x)
#
# NameError: name 'primitiva_sim' is not defined

# %%
def primitiva(f,x):
    integral, h=np.zeros_like(f), x[1]-x[0]
    integral[0] = f[0] +26*f[1] -4*f[2] +6*f[3] -3*f[4]
    for i in range(1,len(x)-4):
        integral[i] += integral[i-1] +(f[i] +26*f[i+1] -4*f[i+2] +6*
        print(i)
    for i in range(-4,1):
        integral[i-1] = integral[i-1]+ (23*f[i-1]+ 26*f[i-2]- 4*f[]
        print(i-1)
    return integra

# %%
x=np.linspace
